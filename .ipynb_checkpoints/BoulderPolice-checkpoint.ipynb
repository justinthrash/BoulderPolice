# %% [markdown]
# # Import Libraries and Data

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from pandas import Series, DataFrame

# %%
df = pd.read_csv('BPD_Call_Log.csv')

# %%
dictionary = pd.read_csv('bpd_call_log_data_dictionary.csv')

# %% [markdown]
# # Clean up data

# %% [markdown]
# ### Fill in missing ResponseDates from Incident_IDs

# %%
df.loc[df['ResponseDate'].str.len() == 1, 'ResponseDate'] = df['Incident_ID'] #replace single digits

# %%
df['ResponseDate'].apply(pd.to_datetime, errors='coerce'); #change column to datetime

# %% [markdown]
# ### Replace missing Problems

# %%
df['Problem'].fillna(df['CaseNumber'], inplace=True) #fill nans

# %%
df.loc[df['Problem'].str[:2] == '20', 'Problem'] = df['CaseNumber'] #replace problems that start with a date string

# %%
df.groupby(['Problem']).count()
# Out:
#                                             Incident_ID  ResponseDate  \
# Problem
# ASSAU1B-Assault I/P                                  80            80
# ASSAU2B - Assault J/O                                19            19
# ASSAU3B-Assault C                                    31            31
# ASSISB-Assist                                       289           289
# BURGL1B - Burglary I/P                              156           156
# CIVILB - Civil Assist                               113           113
# COENFB - Code Enforcement                             9             9
# CRMIS1B - Criminal Mis I/P                            7             7
# CRMIS2B -Criminal Mis J/O                             8             8
# CRMIS3B - Criminal Mis C                             62            62
# CRTRE1B - Criminal Tresp I/P                          7             7
# CRTRE2B - Criminal Tresp J/O                         13            13
# CRTRE3B - Criminal Tresp C                           73            73
# Case_Number                                           1             1
# DISTU1B - Disturbance I/P                           334           334
# DISTU2B - Disturbance J/O                            66            66
# DRUNKB-Drunk Person                                 113           113
# DTFB-Drug Task Force                                 15            15
# FIREWB-Fire Works Complaints                          5             5
# FISTRB-Structure Fire                               121           121
# FRAUD1B-Fraud I/P                                     1             1
# FRAUD2B-Fraud J/O                                     7             7
# FRAUD3B-Fraud C                                     165           165
# HARAS1B-Harassment I/P                               31            31
# HARAS2B-Harassment J/O                               52            52
# HARAS3B-Harassment C                                109           109
# HAZARB-Hazard                                        74            74
# HOLDB - Held Incident                                 1             1
# INEXP1B-Indecent Exposure I/P                         8             8
# INEXP2B-Indecent Exposure J/O                         8             8
# ...                                                 ...           ...
# LITTEB-Littering                                      4             4
# MAACCB-Major Accident                                26            26
# MENAC1B-Menacing I/P                                 32            32
# MENAC2B-Menacing J/O                                  5             5
# MUNIB-Municipal Ord Violation                         6             6
# NARCOB-Narcotics/Drug viol                           66            66
# NOISEB-Noise Complaint                              301           301
# OAAB-Other Agency Assis                             172           172
# ODORB-Odor Invest                                    32            32
# OPCONB-Open Container                                 2             2
# PARKIB-Parking Complaint/Issue                      332           332
# PDACCB-Property Damage Acc                          407           407
# Period: No Records Returned For  Yesterday            1             1
# ROBBE1B-Robbery I/P                                   4             4
# SASL1B-Sex Assault I/P                                9             9
# SASL2B-Sex Assault J/O                                3             3
# SASL3B-Sex Assault C                                 23            23
# SHOOTB-Shooting                                       6             6
# SHOTS1B-Shots Heard I/P                               5             5
# SHOTS2B-Shots Heard J/O                               7             7
# STABB-Stabbing                                        4             4
# SUSPI1B-Suspicious I/P                              178           178
# SUSPI2B-Suspicious J/O                              136           136
# SUSPI3B-Suspicious C                                 78            78
# TRESP1B-Trespassing I/P                             340           340
# TRESP2B-Trespassing J/O                              35            35
# TRESP3B-Trespassing C                                35            35
# WEAPO1B-Weapon I/P                                   82            82
# WEAPO2B-Weapon J/O                                    3             3
# WEAPO3B-Weapon C                                      1             1
#
#                                             CaseNumber  HundredBlock
# Problem
# ASSAU1B-Assault I/P                                 63            80
# ASSAU2B - Assault J/O                               19            19
# ASSAU3B-Assault C                                   31            30
# ASSISB-Assist                                      289           287
# BURGL1B - Burglary I/P                              61           156
# CIVILB - Civil Assist                              113           110
# COENFB - Code Enforcement                            9             9
# CRMIS1B - Criminal Mis I/P                           7             7
# CRMIS2B -Criminal Mis J/O                            8             8
# CRMIS3B - Criminal Mis C                            62            62
# CRTRE1B - Criminal Tresp I/P                         7             7
# CRTRE2B - Criminal Tresp J/O                        13            13
# CRTRE3B - Criminal Tresp C                          73            73
# Case_Number                                          1             1
# DISTU1B - Disturbance I/P                          334           334
# DISTU2B - Disturbance J/O                           66            66
# DRUNKB-Drunk Person                                113           112
# DTFB-Drug Task Force                                15            15
# FIREWB-Fire Works Complaints                         5             5
# FISTRB-Structure Fire                               14           121
# FRAUD1B-Fraud I/P                                    1             1
# FRAUD2B-Fraud J/O                                    7             7
# FRAUD3B-Fraud C                                    165           165
# HARAS1B-Harassment I/P                              31            31
# HARAS2B-Harassment J/O                              52            52
# HARAS3B-Harassment C                               109           108
# HAZARB-Hazard                                       74            73
# HOLDB - Held Incident                                1             1
# INEXP1B-Indecent Exposure I/P                        8             7
# INEXP2B-Indecent Exposure J/O                        8             8
# ...                                                ...           ...
# LITTEB-Littering                                     4             4
# MAACCB-Major Accident                               24            26
# MENAC1B-Menacing I/P                                29            32
# MENAC2B-Menacing J/O                                 5             5
# MUNIB-Municipal Ord Violation                        6             6
# NARCOB-Narcotics/Drug viol                          66            66
# NOISEB-Noise Complaint                             301           301
# OAAB-Other Agency Assis                            172           172
# ODORB-Odor Invest                                   32            32
# OPCONB-Open Container                                2             2
# PARKIB-Parking Complaint/Issue                     332           331
# PDACCB-Property Damage Acc                         407           406
# Period: No Records Returned For  Yesterday           1             1
# ROBBE1B-Robbery I/P                                  4             4
# SASL1B-Sex Assault I/P                               6             9
# SASL2B-Sex Assault J/O                               3             3
# SASL3B-Sex Assault C                                23            23
# SHOOTB-Shooting                                      6             6
# SHOTS1B-Shots Heard I/P                              5             5
# SHOTS2B-Shots Heard J/O                              7             7
# STABB-Stabbing                                       4             4
# SUSPI1B-Suspicious I/P                             178           177
# SUSPI2B-Suspicious J/O                             136           135
# SUSPI3B-Suspicious C                                78            77
# TRESP1B-Trespassing I/P                            340           339
# TRESP2B-Trespassing J/O                             35            35
# TRESP3B-Trespassing C                               35            35
# WEAPO1B-Weapon I/P                                  49            82
# WEAPO2B-Weapon J/O                                   3             3
# WEAPO3B-Weapon C                                     1             1
#
# [63 rows x 4 columns]

# %%
dictionary
# Out:
#     Column Name                                         Definition
# 0   Incident_ID                        Unique identifier for call.
# 1  ResponseDate          Date and time that the call was received.
# 2    CaseNumber  Case number associated with the incident. Case...
# 3  HundredBlock  Address (rounded up to hundred block location)...
# 4       Problem  Code for the problem associated with the call....

# %%
df['Problem'].unique()
# Out:
# array(['SASL2B-Sex Assault J/O', 'DISTU1B - Disturbance I/P',
#        'WEAPO1B-Weapon I/P', 'TRESP1B-Trespassing I/P',
#        'SUSPI1B-Suspicious I/P', 'CRTRE1B - Criminal Tresp I/P',
#        'PDACCB-Property Damage Acc', 'STABB-Stabbing',
#        'ASSAU1B-Assault I/P', 'HARAS1B-Harassment I/P',
#        'CRMIS1B - Criminal Mis I/P', 'SHOTS1B-Shots Heard I/P',
#        'INEXP1B-Indecent Exposure I/P', 'OAAB-Other Agency Assis',
#        'MENAC1B-Menacing I/P', 'MENAC2B-Menacing J/O',
#        'SASL1B-Sex Assault I/P', 'SHOOTB-Shooting', 'HAZARB-Hazard',
#        'NARCOB-Narcotics/Drug viol', 'ASSISB-Assist',
#        'DRUNKB-Drunk Person', 'FRAUD1B-Fraud I/P',
#        'ASSAU2B - Assault J/O', 'ROBBE1B-Robbery I/P',
#        'FISTRB-Structure Fire', 'BURGL1B - Burglary I/P',
#        'MAACCB-Major Accident', 'NOISEB-Noise Complaint',
#        'SHOTS2B-Shots Heard J/O', 'SUSPI2B-Suspicious J/O',
#        'DISTU2B - Disturbance J/O', 'CIVILB - Civil Assist',
#        'TRESP2B-Trespassing J/O', 'CRMIS2B -Criminal Mis J/O',
#        'FRAUD2B-Fraud J/O', 'HARAS2B-Harassment J/O',
#        'CRTRE2B - Criminal Tresp J/O', 'WEAPO2B-Weapon J/O',
#        'INEXP2B-Indecent Exposure J/O', 'LILAWB-Liquor Law',
#        'CRMIS3B - Criminal Mis C', 'CRTRE3B - Criminal Tresp C',
#        'ASSAU3B-Assault C', 'PARKIB-Parking Complaint/Issue',
#        'HARAS3B-Harassment C', 'SUSPI3B-Suspicious C',
#        'ODORB-Odor Invest', 'SASL3B-Sex Assault C', 'FRAUD3B-Fraud C',
#        'TRESP3B-Trespassing C', 'FIREWB-Fire Works Complaints',
#        'DTFB-Drug Task Force', 'LITTEB-Littering',
#        'INEXP3B-Indecent Exposure C', 'OPCONB-Open Container',
#        'COENFB - Code Enforcement', 'MUNIB-Municipal Ord Violation',
#        'WEAPO3B-Weapon C', 'HOLDB - Held Incident',
#        'KIDNA1B-Kidnapping I/P',
#        'Period: No Records Returned For  Yesterday', 'Case_Number'],
#       dtype=object)
